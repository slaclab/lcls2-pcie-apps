# %%
import matplotlib.pyplot as plt
import numpy as np
import sys

def byte_info(p,start,end):
    n_bytes = ""
    for i in p[start:end][::-1]:
        n_bytes += '{0:08b}'.format(i)
    n_bytes = int('0b'+n_bytes,2)
    print(p[start:end],"len = "+str(len(p)),"n bytes in frame = "+str(n_bytes))

# %% [markdown]
# # no prescaling

# %%
p1 = bytearray(b'1\xa8\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x8e d2\xee\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\x00\x00\x02\x10\x01\x00\x00\x000\x00\x00\x00\x00\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x001P')
print(len(p1))
# Out:
# 4304

# %% [markdown]
# # prescaled FEX background

# %%
p2 = bytearray(b'1Q\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10F\x15\x0b\x97\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\x00\x00\x02\x10\x01\x00\x00\x000\x00\x00\x00\x00\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x001Q\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x000')

print(len(p2))
# Out:
# 2224

# %% [markdown]
# # prescaled core

# %%
p3 = bytearray(b'1B\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00p\xca\xc7\x10\xf5\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\x00\x00\x02\x10\x01\x00\x00\x000\x00\x00\x00\x00\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x001BP\x08\x00\x00\x01\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x00')
print(len(p3))
# Out:
# 2224

# %% [markdown]
# # both prescaled

# %%
p4 = bytearray(b'1?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf8\x87q\x13\xee\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\x00\x00\x02\x10\x01\x00\x00\x000\x00\x00\x00\x00\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x001?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x000\x00\x00\x00\x01\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x00')
print(len(p4))
# Out:
# 144

# %%
start = 64
end = start+4
print("i = " +(str(start)))
byte_info(p4,start,end) #no full images
# Out:
# i = 64
# bytearray(b'0\x00\x00\x00') len = 144 n bytes in frame = 48

# %% [markdown]
# # finding headers

# %%
print(p4[:32])
print(p4)
# Out:
# bytearray(b'1?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf8\x87q\x13\xee\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf8\x87q\x13\xee\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\x00\x00\x02\x10\x01\x00\x00\x000\x00\x00\x00\x00\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x001?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x000\x00\x00\x00\x01\x02\x00\x03\x00\x00\x00\x00\x00\x00\x00\x00')

# %%
header = '{0:08b}'.format(p1[0])
header
# Out:
# '00110001'

# %%
header = '{0:08b}'.format(p1[0])
p=p4
for i in range(len(p)):
    if '{0:08b}'.format(p[i]) == header:
        print(i)
# Out:
# 0
# 80

# %% [markdown]
# # comparisons

# %%
def byte_info(p,start,end):
    n_bytes = ""
    for i in p[start:end][::-1]:
        n_bytes += '{0:08b}'.format(i)
    n_bytes = int('0b'+n_bytes,2)
    print(p[start:end],"len = "+str(len(p)),"n bytes in frame = "+str(n_bytes))

# %%
for i in range(-16,-15):
    start = i
    end = start+4
    print("i = " +(str(start)))
    byte_info(p1,start,end) #two full images
    byte_info(p2,start,end) #fex background prescaled out. only core remaining
    byte_info(p3,start,end) #core prescaled out. fex full image remaining
    byte_info(p4,start,end) #no full images
# Out:
# i = -16
# bytearray(b'\x10\x08\x00\x00') len = 4304 n bytes in frame = 2064
# bytearray(b'\x10\x08\x00\x00') len = 2224 n bytes in frame = 2064
# bytearray(b'P\x08\x00\x00') len = 2224 n bytes in frame = 2128
# bytearray(b'0\x00\x00\x00') len = 144 n bytes in frame = 48

# %%
for i in [-2096,-2112]:
    start = i
    end = start +4
    print(start)
    byte_info(p1,start,end) #two full images
    byte_info(p2,start,end) #fex background prescaled out. only core remaining
# Out:
# -2096
# bytearray(b'P\x08\x00\x00') len = 4304 n bytes in frame = 2128
# bytearray(b'0\x00\x00\x00') len = 2224 n bytes in frame = 48
# -2112
# bytearray(b'\x10\x08\x00\x00') len = 4304 n bytes in frame = 2064
# bytearray(b'\x10\x00\x00\x00') len = 2224 n bytes in frame = 16

# %%
for i in [-2096-2128-32,-2112-2128-32]:
    start = i
    end = start +4
    print(start)
    byte_info(p1,start,end) #two full images
# Out:
# -4256
# bytearray(b'\x00\x00\x00\x00') len = 4304 n bytes in frame = 0
# -4272
# bytearray(b'\x00\x00\x00\x00') len = 4304 n bytes in frame = 0

# %%
for i in range(128-16,128-16+1):
    start = i
    end = start+4
    print("i = " +(str(start)))
    byte_info(p1,start,end) #two full images
    byte_info(p2,start,end) #fex background prescaled out. only core remaining
    byte_info(p3,start,end) #core prescaled out. fex full image remaining
    byte_info(p4,start,end) #no full images
# Out:
# i = 112
# bytearray(b'\x10\x00\x00\x00') len = 4304 n bytes in frame = 16
# bytearray(b'\x10\x00\x00\x00') len = 2224 n bytes in frame = 16
# bytearray(b'\x10\x00\x00\x00') len = 2224 n bytes in frame = 16
# bytearray(b'\x10\x00\x00\x00') len = 144 n bytes in frame = 16

# %%
start = -16-(2064-16 )
end = start + 4
byte_info(p1,start,end)
# Out:
# bytearray(b'\x00\x00\x01\x00') len = 4304 n bytes in frame = 65536

# %%
import numpy as np

class eventBuilderParser():
    def __init__(self):        
        return

    def frames_to_position(self,frame_bytearray,position):
        return int('0b'+'{0:08b}'.format(frame_bytearray[position+1])+'{0:08b}'.format(frame_bytearray[position]),2)
    
    def _checkForSubframes(self):
        self.sub_is_fullframe = [False]*len(self.frame_list)
        
        for i in range(len(self.frame_list)):
            
            if self.main_header[:2] == self.frame_list[i][:self.HEADER_WIDTH ][:2]:
                self.sub_is_fullframe[i] = True
        
        return
    
    def _resolveSubFrames(self):
        self._checkForSubframes()
        self.sub_frames = [False]*len(self.frame_list)
        for i in range(len(self.frame_list)):
            if self.sub_is_fullframe[i]:
                self.sub_frames[i] =  eventBuilderParser()
                #print("length = ",len(self.frame_list[i]))
                self.sub_frames[i].parseArray(self.frame_list[i])
                self.frame_list[i] = False
        return
    
    def print_info(self):
        for i in self.__dict__:
            if i != "frame_list" and type(self.__dict__[i]) is not bytearray:
                print(i," = ",self.__dict__[i])
                
        for i in range(len(self.sub_is_fullframe)):
            if(self.sub_is_fullframe[i]):
                print("\nsubframe = ",i)
                self.sub_frames[i].print_info()
                
        return
        
    def parseArray(self,frame_bytearray:bytearray):
        self.frame_bytes     = len(frame_bytearray)
        self.main_header     = frame_bytearray[0:16]

        self.version                = self.main_header[0] & int('00001111', 2)
        self.axi_stream_bit_width   = 8*2**((self.main_header[0] >> 4) + 1)
        self.sequence_count         = self.main_header[1]
        self.HEADER_WIDTH           = int(self.axi_stream_bit_width/8)
        
        
        self.frame_sizes_reversed         = [self.frames_to_position(frame_bytearray,-16)]
        self.frame_positions_reversed     = [[self.frame_bytes-16-self.frame_sizes_reversed[0],self.frame_bytes-16]] #[start, and]
        self.frame_list                   = [frame_bytearray[self.frame_positions_reversed[-1][0]:self.frame_positions_reversed[-1][1]]]
        
        self.tdest                        = [frame_bytearray[-12]]
        
        
        parsed_frame_size = sum(self.frame_sizes_reversed) +(len(self.frame_sizes_reversed)+1)*self.HEADER_WIDTH
        #print("parsing")
        while(len(frame_bytearray)>parsed_frame_size):
            #print(len(frame_bytearray))
            self.frame_sizes_reversed.append(self.frames_to_position(frame_bytearray,self.frame_positions_reversed[-1][0]-16))
            
            self.frame_positions_reversed.append([self.frame_positions_reversed[-1][0]-16-self.frame_sizes_reversed[-1],self.frame_positions_reversed[-1][0]-16]) #[start, and]            
            
            self.frame_list.append(frame_bytearray[self.frame_positions_reversed[-1][0]:self.frame_positions_reversed[-1][1]])
            self.tdest.append(frame_bytearray[self.frame_positions_reversed[-1][1]+4])
            
            
          
            parsed_frame_size = sum(self.frame_sizes_reversed) +(len(self.frame_sizes_reversed)+1)*self.HEADER_WIDTH
        
        #self.sub_is_fullframe = [False]*len(self.frame_list)
        self._resolveSubFrames()
        
        return
    
class timeToolParser(eventBuilderParser):
    def parseData(self,frame_bytearray:bytearray):
        self.parseArray(frame_bytearray)
        
        
        try:
            timing_bus_idx           = [i[0] for i in enumerate(self.tdest) if i[1]==0][0] #timing bus always has tdest of 0
            self.timing_bus          = self.frame_list[timing_bus_idx]  #frame_bytearray[16:32]
        except IndexError:
            self.timing_bus = None
        
        sub_frame_idx            = [i[0] for i in enumerate(self.tdest) if i[1]==1][0]
        edge_pos_idx             = [i[0] for i in enumerate(self.sub_frames[sub_frame_idx].tdest) if i[1]==0][0]
        self.edge_position       = self.sub_frames[sub_frame_idx].frame_list[edge_pos_idx][0] + self.sub_frames[sub_frame_idx].frame_list[edge_pos_idx][1]*256
        
        try:
            bkg_frame_idx            = [i[0] for i in enumerate(self.sub_frames[sub_frame_idx].tdest) if i[1]==1][0]
            self.background_frame    = self.sub_frames[sub_frame_idx].frame_list[bkg_frame_idx]
        except IndexError:    
            self.background_frame    = None

        try:
            prescaled_frame_idx      = [i[0] for i in enumerate(self.tdest) if i[1]==2][0]
            self.prescaled_frame     = self.frame_list[prescaled_frame_idx] 
        except IndexError:
            self.prescaled_frame     = None
            
        
        
        
    
        return

# %%
full_frame = timeToolParser()
full_frame.parseData(p1)
full_frame.print_info()
#print(full_frame.edge_position)
# Out:
# frame_bytes  =  4304
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  168
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [2064, 2128, 48]
# frame_positions_reversed  =  [[2224, 4288], [80, 2208], [16, 64]]
# tdest  =  [2, 1, 0]
# sub_is_fullframe  =  [False, True, False]
# sub_frames  =  [False, <__main__.eventBuilderParser object at 0x7f073bc399e8>, False]
# edge_position  =  2044
#
# subframe =  1
# frame_bytes  =  2128
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  168
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [2064, 16]
# frame_positions_reversed  =  [[48, 2112], [16, 32]]
# tdest  =  [1, 0]
# sub_is_fullframe  =  [False, False]
# sub_frames  =  [False, False]

# %%
full_frame = timeToolParser()
full_frame.parseData(p2)
full_frame.print_info()
#print(full_frame.edge_position)
# Out:
# frame_bytes  =  2224
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  81
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [2064, 48, 48]
# frame_positions_reversed  =  [[144, 2208], [80, 128], [16, 64]]
# tdest  =  [2, 1, 0]
# sub_is_fullframe  =  [False, True, False]
# sub_frames  =  [False, <__main__.eventBuilderParser object at 0x7f073bc399e8>, False]
# edge_position  =  2047
# background_frame  =  None
#
# subframe =  1
# frame_bytes  =  48
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  81
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [16]
# frame_positions_reversed  =  [[16, 32]]
# tdest  =  [0]
# sub_is_fullframe  =  [False]
# sub_frames  =  [False]

# %%
full_frame = timeToolParser()
full_frame.parseData(p3)
full_frame.print_info()
#print(full_frame.edge_position)
# Out:
# frame_bytes  =  2224
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  66
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [2128, 48]
# frame_positions_reversed  =  [[80, 2208], [16, 64]]
# tdest  =  [1, 0]
# sub_is_fullframe  =  [True, False]
# sub_frames  =  [<__main__.eventBuilderParser object at 0x7f073bc39eb8>, False]
# edge_position  =  2047
# prescaled_frame  =  None
#
# subframe =  0
# frame_bytes  =  2128
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  66
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [2064, 16]
# frame_positions_reversed  =  [[48, 2112], [16, 32]]
# tdest  =  [1, 0]
# sub_is_fullframe  =  [False, False]
# sub_frames  =  [False, False]

# %%
full_frame = timeToolParser()
full_frame.parseData(p4)
#print(full_frame.edge_position)
full_frame.print_info()
# Out:
# frame_bytes  =  144
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  63
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [48, 48]
# frame_positions_reversed  =  [[80, 128], [16, 64]]
# tdest  =  [1, 0]
# sub_is_fullframe  =  [True, False]
# sub_frames  =  [<__main__.eventBuilderParser object at 0x7f073bc39b70>, False]
# edge_position  =  2047
# background_frame  =  None
# prescaled_frame  =  None
#
# subframe =  0
# frame_bytes  =  48
# version  =  1
# axi_stream_bit_width  =  128
# sequence_count  =  63
# HEADER_WIDTH  =  16
# frame_sizes_reversed  =  [16]
# frame_positions_reversed  =  [[16, 32]]
# tdest  =  [0]
# sub_is_fullframe  =  [False]
# sub_frames  =  [False]

# %%
start , end = 0,16
print("_______________________\np1")
print(p1[start:end])
print(p1[start+80:end+80])
print("_______________________\np2")
print(p2[start:end])
print(p2[start+80:end+80])
print("_______________________\np3")
print(p3[start:end])
print(p3[start+80:end+80])
print("_______________________\np4")
print(p4[start:end])
print(p4[start+80:end+80])
# Out:
# _______________________
# p1
# bytearray(b'1\xa8\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1\xa8\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# _______________________
# p2
# bytearray(b'1Q\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1Q\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# _______________________
# p3
# bytearray(b'1B\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1B\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# _______________________
# p4
# bytearray(b'1?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')

# %%
print(p1[80:96])
print(p1[:16])
print(p2[:16])
print(p3[:16])
print(p4[:16])
# Out:
# bytearray(b'1\xa8\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1\xa8\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1Q\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1B\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# bytearray(b'1?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')

# %% [markdown]
# # copy pasta

# %%
import setupLibPaths
import TimeToolDev
import sys
import time
import gc
import argparse
import numpy as np
cl = TimeToolDev.TimeToolDev(
    dataDebug = True
)
clear
cl.Application.AppLane[0].Fex.EVC_placeholder.DialInPreScaling.set(0x0)
cl.Application.AppLane[0].Prescale.DialInPreScaling.set(0x0)
cl.StartRun()
cl.StopRun()
p = bytearray(cl.TimeToolRx.frame.getPayload())
cl.TimeToolRx.frame.read(p,0)
len(p)
pwd
history
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-265-6dc0823a59f0> in <module>
# ----> 1 import setupLibPaths
#       2 import TimeToolDev
#       3 import sys
#       4 import time
#       5 import gc
#
# ModuleNotFoundError: No module named 'setupLibPaths'

# %%
line_spacing = np.array([3-0,8-3,16-8,32-16,55-32,128-55,128,128])
byte_size    = np.array([0x40,0x60,0x90,0x110,0x180,0x4a0,0x810,0x810])

# %%
byte_size
# Out:
# array([  64,   96,  144,  272,  384, 1184, 2064, 2064])

# %%
len(byte_size)
# Out:
# 8

# %%
len(line_spacing)
# Out:
# 8

# %%
plt.plot(line_spacing,byte_size,'o',linewidth='1',linestyle='-')
plt.show()
